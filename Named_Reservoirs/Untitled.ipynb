# %%
import pandas as pd
import geopandas as gpd

# %%
gdf = gpd.read_file('Named_Reservoirs9.shp')
gdf
# Out:
#                     NAME  SHAPE_Leng  SHAPE_Area        lat         lon  \
# 0       WILSON RESERVOIR    0.034915    0.000028 -37.510018  144.018549
# 1    SUGARLOAF RESERVOIR    0.212903    0.000438 -37.672015  145.305467
# 2    SUGARLOAF RESERVOIR    0.212903    0.000438 -37.672015  145.305467
# 3             GREEN LAKE    0.155045    0.000715 -36.435338  144.834187
# 4             GREEN LAKE    0.075718    0.000170 -36.792870  142.292810
# ..                   ...         ...         ...        ...         ...
# 424       TINANA BARRAGE    0.034002    0.000012 -25.571684  152.713346
# 425      LAKE GLENMAGGIE    0.550671    0.001746 -37.906605  146.768497
# 426     MURRAY 2 PONDAGE    0.054875    0.000014 -36.241612  148.185751
# 427     DUNHAM PILOT DAM    0.313080    0.000950 -16.032589  128.363891
# 428       BLUE ROCK LAKE    0.481989    0.000879 -38.061382  146.200390
#
#       Area_calc                                       staion_nam   gauge_ID  \
# ...

# %%
gdf['Area_calc_m'] = gdf['geometry'].area
gdf
# Out:
# /tmp/ipykernel_123/2007140935.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf['Area_calc_m'] = gdf['geometry'].area
#                     NAME  SHAPE_Leng  SHAPE_Area        lat         lon  \
# 0       WILSON RESERVOIR    0.034915    0.000028 -37.510018  144.018549
# 1    SUGARLOAF RESERVOIR    0.212903    0.000438 -37.672015  145.305467
# 2    SUGARLOAF RESERVOIR    0.212903    0.000438 -37.672015  145.305467
# 3             GREEN LAKE    0.155045    0.000715 -36.435338  144.834187
# 4             GREEN LAKE    0.075718    0.000170 -36.792870  142.292810
# ..                   ...         ...         ...        ...         ...
# 424       TINANA BARRAGE    0.034002    0.000012 -25.571684  152.713346
# 425      LAKE GLENMAGGIE    0.550671    0.001746 -37.906605  146.768497
# ...
