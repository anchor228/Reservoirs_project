# %%
import pandas as pd 
import geopandas as gpd
import numpy as np

# %%
gdf = gpd.read_file('points_with_ID - Copy - Copy.shp')
gdf
# Out:
#                                             staion_nam     gauge_ID  \
# 0    10 Mile Brook Dam Water Level Daily Value, Sou...  PI_357693.1
# 1                                                  284          D24
# 2                                   2km N Warringee Pt     A4261155
# 3                                      3km W Pt McLeay     A4261156
# 4                                                  40A          D21
# ..                                                 ...          ...
# 608                                    YARRADDA LAGOON     41010302
# 609                         Yabba Ck at Borumba Dam HW      138112A
# 610                                    Yarrawonga Weir    sp-o10814
# 611                                          Yealering      6150002
# 612                                       Yerrabi Pond       410791
#
#            lat         lon  NEAR_FID  NEAR_DIST AHGFNetwor AHGFNetw_1  \
# 0   -33.963617  115.124899        -1  -1.000000       None       None
# ...

# %%
gdf['NEAR_FID'] = gdf['NEAR_FID'].astype(int)

# %%
gdf2 = gdf[gdf.NEAR_FID > 0]
gdf2 = gdf2[['staion_nam', 'gauge_ID', 'lat', 'lon', 'NEAR_FID', 'geometry']]
gdf2
# Out:
#                          staion_nam   gauge_ID        lat         lon  \
# 2                2km N Warringee Pt   A4261155 -35.676602  139.250269
# 3                   3km W Pt McLeay   A4261156 -35.514813  139.064752
# 5               4km W Pomanda Point   A4261158 -35.429761  139.268689
# 6                     7km SE Milang   A4261157 -35.437269  139.039820
# 8    ARTHURS LAKE - AT PUMP STATION      418.1 -41.988306  146.862472
# ..                              ...        ...        ...         ...
# 604                 YAN YEAN RES HG    229406A -37.552300  145.129000
# 607             YARRA RIV-UY RES HG    229102A -37.673072  145.900960
# 609      Yabba Ck at Borumba Dam HW    138112A -26.509675  152.581865
# 610                 Yarrawonga Weir  sp-o10814 -36.010308  146.091535
# 612                    Yerrabi Pond     410791 -35.177194  149.127833
#
#      NEAR_FID                     geometry
# 2          18  POINT (139.25027 -35.67660)
# ...
