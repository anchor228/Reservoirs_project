# %%
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
df = pd.read_csv('Gauge_points/did_intersect.csv')
gdf = gpd.read_file('Named_Reservoirs/Named_Reservoirs.shp')
gdf = gdf.sort_values(by=['NAME'])
gdf = gdf.set_index(['NAME'])
gdf
# Out:
#                       SHAPE_Leng  SHAPE_Area     Area_calc        lat  \
# NAME
# 1400 DAM                0.022747    0.000018  1.949725e+05 -26.695969
# 18 MILE DAM             0.011191    0.000005  5.702066e+04 -20.846571
# ADVANCETOWN LAKE        1.022664    0.001356  1.477195e+07 -28.076309
# ARTHURS LAKE            0.781053    0.006971  6.417353e+07 -41.980583
# AWOONGA RESERVOIR       2.526435    0.005715  6.434438e+07 -24.121393
# ...                          ...         ...           ...        ...
# YARRIAMBIACK CREEK      0.014854    0.000005  4.842764e+04 -36.076802
# YARRIAMBIACK CREEK      0.015807    0.000003  2.959606e+04 -36.072939
# YELDULKNIE RESERVOIR    0.024696    0.000024  2.484488e+05 -33.690528
# YELLOW WATERHOLE        0.026846    0.000015  1.724182e+05 -18.636822
# YERRABI POND            0.043975    0.000026  2.610250e+05 -35.176381
#
#                              lon  \
# NAME
# 1400 DAM              147.500733
# 18 MILE DAM           141.746734
# ...

# %%
names = list(df['NAME'])

for i in names:
    gdf2 = gdf.loc[i]
    continue
gdf2
# Out:
# SHAPE_Leng                                            0.0439754
# SHAPE_Area                                          2.58285e-05
# Area_calc                                                261025
# lat                                                    -35.1764
# lon                                                     149.131
# geometry      POLYGON ((149.1388375 -35.17465950000002, 149....
# Name: YERRABI POND, dtype: object

# %%
gdf_list[1]
# Out:
# SHAPE_Leng                                             0.781053
# SHAPE_Area                                           0.00697139
# Area_calc                                           6.41735e+07
# lat                                                    -41.9806
# lon                                                     146.924
# geometry      POLYGON ((146.909754 -41.93936350000001, 146.9...
# Name: ARTHURS LAKE, dtype: object
